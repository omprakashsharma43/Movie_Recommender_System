# %% [markdown]
# # Movie Recommender System

# %%
import numpy as np
import pandas as pd

# %%
movies= pd.read_csv("tmdb_5000_movies.csv")
credits=pd.read_csv("tmdb_5000_credits.csv")

# %%
movies= movies.merge(credits, on= "title")
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
# # Movies Columns :-
# genres
# id
# keywords
# title
# release_date
# overview
# cast 
# crew

movies = movies[["movie_id", "title", "release_date", "overview", "genres", "keywords", "cast", "crew"]]
movies
# Out:
#       movie_id                                     title release_date  \
# 0        19995                                    Avatar   2009-12-10
# 1          285  Pirates of the Caribbean: At World's End   2007-05-19
# 2       206647                                   Spectre   2015-10-26
# 3        49026                     The Dark Knight Rises   2012-07-16
# 4        49529                               John Carter   2012-03-07
# ...        ...                                       ...          ...
# 4804      9367                               El Mariachi   1992-09-04
# 4805     72766                                 Newlyweds   2011-12-26
# 4806    231617                 Signed, Sealed, Delivered   2013-10-13
# 4807    126186                          Shanghai Calling   2012-05-03
# 4808     25975                         My Date with Drew   2005-08-05
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# ...

# %%
movies.isnull().sum()
# Out:
# movie_id        0
# title           0
# release_date    1
# overview        3
# genres          0
# keywords        0
# cast            0
# crew            0
# dtype: int64

# %%
movies.dropna(inplace = True)
movies.isnull().sum()
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\1921884608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace = True)
# movie_id        0
# title           0
# release_date    0
# overview        0
# genres          0
# keywords        0
# cast            0
# crew            0
# dtype: int64

# %%
movies.shape
# Out:
# (4805, 8)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Convert genres to get only three names

# %%
import ast
ast.literal_eval
def convert(data):
    L = []
    for i in ast.literal_eval(data):
        L.append(i["name"])
    return L

# %%
movies["genres"] = movies["genres"].apply(convert)
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\697450761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["genres"] = movies["genres"].apply(convert)

# %%
movies["keywords"] = movies["keywords"].apply(convert)
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\2573823842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["keywords"] = movies["keywords"].apply(convert)

# %% [markdown]
# Convert cast to get only three names

# %%
def convert_cast(data):
    L = []
    counts=0
    for i in ast.literal_eval(data):
        if counts < 3 :
            L.append(i["name"])
            counts +=1    
    return L

# %%
movies["cast"] = movies["cast"].apply(convert_cast)
movies.head()
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\3558102170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["cast"] = movies["cast"].apply(convert_cast)
#    movie_id                                     title release_date  \
# 0     19995                                    Avatar   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End   2007-05-19
# 2    206647                                   Spectre   2015-10-26
# 3     49026                     The Dark Knight Rises   2012-07-16
# 4     49529                               John Carter   2012-03-07
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# ...

# %% [markdown]
# Convert crew to get only director name

# %%
def fetch_director(data):
    L = []
    for i in ast.literal_eval(data):
        if i["job"] == "Director" :
            L.append(i["name"])
            break
    return L

# %%
movies["crew"] = movies["crew"].apply(fetch_director)
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\798350407.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["crew"] = movies["crew"].apply(fetch_director)

# %%
movies["director"] = movies["crew"]
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\822151440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["director"] = movies["crew"]

# %% [markdown]
# convert movies["overview"] into str

# %%
movies["overview"] = movies["overview"].apply(lambda x : x.split())
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\1242990208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["overview"] = movies["overview"].apply(lambda x : x.split())

# %% [markdown]
# Remove space between names
# Sam Worthington
# -> SamWorthington

# %%
movies["cast"] = movies["cast"].apply(lambda x: [i.replace(" ","") for i in x])
movies["genres"] = movies["genres"].apply(lambda x: [i.replace(" ","") for i in x])
movies["crew"] = movies["crew"].apply(lambda x: [i.replace(" ","") for i in x])
movies["keywords"] = movies["keywords"].apply(lambda x: [i.replace(" ","") for i in x])
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\76966540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["cast"] = movies["cast"].apply(lambda x: [i.replace(" ","") for i in x])
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\76966540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["genres"] = movies["genres"].apply(lambda x: [i.replace(" ","") for i in x])
# ...

# %%
movies.head()
# Out:
#    movie_id                                     title release_date  \
# 0     19995                                    Avatar   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End   2007-05-19
# 2    206647                                   Spectre   2015-10-26
# 3     49026                     The Dark Knight Rises   2012-07-16
# 4     49529                               John Carter   2012-03-07
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# ...

# %% [markdown]
# Create Tag Column which contain all columns ["genres", "keywords", "cast", "crew"]

# %%
movies["tags"] = movies["overview"] + movies["genres"] + movies["keywords"] + movies["cast"] + movies["crew"]
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\1952502015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["tags"] = movies["overview"] + movies["genres"] + movies["keywords"] + movies["cast"] + movies["crew"]

# %%
movies.head()
# Out:
#    movie_id                                     title release_date  \
# 0     19995                                    Avatar   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End   2007-05-19
# 2    206647                                   Spectre   2015-10-26
# 3     49026                     The Dark Knight Rises   2012-07-16
# 4     49529                               John Carter   2012-03-07
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# ...

# %%
df=movies[["movie_id", "title","release_date","director", "tags"]]
df["tags"] = df["tags"].apply(lambda x: " ".join(x))
df["tags"] = df["tags"].apply(lambda x: x.lower())
df
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\2770302822.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"] = df["tags"].apply(lambda x: " ".join(x))
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\2770302822.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"] = df["tags"].apply(lambda x: x.lower())
#       movie_id                                     title release_date  \
# ...

# %% [markdown]
# For coverting verb Forms and helping verb into verb

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
# ps.stem("loving") # for example

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
df["tags"] = df["tags"].apply(stem)
# Out:
# C:\Users\OM PRAKASH SHARMA\AppData\Local\Temp\ipykernel_27032\552104661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tags"] = df["tags"].apply(stem)

# %% [markdown]
# ### Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(max_features=5000, stop_words='english')
vectors = cv.fit_transform(df["tags"]).toarray()

# %%
vectors.shape
# Out:
# (4805, 5000)

# %% [markdown]
# For similarity checking in movies using cosine_similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)
print(similarity)
# Out:
# [[1.         0.08346223 0.0860309  ... 0.04499213 0.         0.        ]
#  [0.08346223 1.         0.06063391 ... 0.02378257 0.         0.02615329]
#  [0.0860309  0.06063391 1.         ... 0.02451452 0.         0.        ]
#  ...
#  [0.04499213 0.02378257 0.02451452 ... 1.         0.03962144 0.04229549]
#  [0.         0.         0.         ... 0.03962144 1.         0.08714204]
#  [0.         0.02615329 0.         ... 0.04229549 0.08714204 1.        ]]

# %%
sorted(list(enumerate(similarity[0])),reverse=True, key = lambda x:x[1]) # when sorting index position loose then use enumirate
# Out:
# [(0, np.float64(1.0000000000000002)),
#  (1214, np.float64(0.28676966733820225)),
#  (2405, np.float64(0.26901379342448517)),
#  (3728, np.float64(0.2605130246476754)),
#  (507, np.float64(0.255608593705383)),
#  (539, np.float64(0.25038669783359574)),
#  (582, np.float64(0.24511108480187255)),
#  (1202, np.float64(0.24455799402225925)),
#  (1192, np.float64(0.2367785320221084)),
#  (61, np.float64(0.23179316248638276)),
#  (778, np.float64(0.23174488732966073)),
#  (4046, np.float64(0.2278389747471728)),
#  (1916, np.float64(0.2252817784447915)),
#  (2782, np.float64(0.21853668936906193)),
#  (172, np.float64(0.21239769762143662)),
#  (972, np.float64(0.2108663315950723)),
#  (322, np.float64(0.2105263157894737)),
#  (2329, np.float64(0.20443988269091456)),
#  (3606, np.float64(0.20437977982832192)),
#  (260, np.float64(0.20395079136182276)),
#  (151, np.float64(0.2029530274475215)),
#  (4190, np.float64(0.2029530274475215)),
#  (1440, np.float64(0.20277677641345318)),
# ...

# %%
df
# Out:
#       movie_id                                     title release_date  \
# 0        19995                                    Avatar   2009-12-10
# 1          285  Pirates of the Caribbean: At World's End   2007-05-19
# 2       206647                                   Spectre   2015-10-26
# 3        49026                     The Dark Knight Rises   2012-07-16
# 4        49529                               John Carter   2012-03-07
# ...        ...                                       ...          ...
# 4804      9367                               El Mariachi   1992-09-04
# 4805     72766                                 Newlyweds   2011-12-26
# 4806    231617                 Signed, Sealed, Delivered   2013-10-13
# 4807    126186                          Shanghai Calling   2012-05-03
# 4808     25975                         My Date with Drew   2005-08-05
#
#                  director                                               tags
# ...

# %% [markdown]
# Remommend Function

# %%
def recommend(movie):
    movie_index = df[df["title"] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse=True, key = lambda x:x[1])[0:6] # when sorting index position loose then use enumirate
    
    for i in movies_list:
        print(df.iloc[i[0]].title, df.iloc[i[0]].director, df.iloc[i[0]].release_date )

# %%
print(recommend("The Avengers"))
# Out:
# The Avengers ['Joss Whedon'] 2012-04-25
# Iron Man 3 ['Shane Black'] 2013-04-18
# Avengers: Age of Ultron ['Joss Whedon'] 2015-04-22
# Captain America: Civil War ['Anthony Russo'] 2016-04-27
# Captain America: The First Avenger ['Joe Johnston'] 2011-07-22
# Iron Man ['Jon Favreau'] 2008-04-30
# None

# %% [markdown]
# Pickle File

# %%
import pickle

pickle.dump(df.to_dict(), open('movie_dict.pkl','wb'))
pickle.dump(similarity, open('similarity.pkl','wb'))
